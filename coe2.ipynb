# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Advertising.csv')
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
data.head(5)
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.tail(10)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 190         191   39.5   41.1        5.8   10.8
# 191         192   75.5   10.8        6.0    9.9
# 192         193   17.2    4.1       31.6    5.9
# 193         194  166.8   42.0        3.6   19.6
# 194         195  149.7   35.6        6.0   17.3
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
sns.histplot(x=data['TV'])
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(x=data['TV'],kde =True)
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(x=data['TV'],kde=True,bins=40)
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
data['TV'].skew()
# Out:
# np.float64(-0.06985336213274573)

# %%
data['Radio'].skew()
# Out:
# np.float64(0.09417463149664404)

# %%
data['Newspaper'].skew()
# Out:
# np.float64(0.8947204074986175)

# %%
sns.scatterplot(x=data['TV'],y=data['Sales'])
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.scatterplot(x=data['Radio'],y=data['Sales'])
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.scatterplot(x=data['Newspaper'],y=data['Sales'])
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
Key correlations with Sales:

TV vs Sales (≈ 0.78)
Strong positive correlation.
TV advertising has the highest impact on Sales among all media.
    
Radio vs Sales (≈ 0.58)
Moderate positive correlation.
Radio advertising also contributes significantly to Sales, but less than TV.
    
Newspaper vs Sales (≈ 0.23)
Weak positive correlation.
Newspaper ads have a limited influence on Sales.
Relationships among advertising channels
                    
Radio vs Newspaper (≈ 0.35)
Moderate correlation, suggesting some overlap in campaigns or audience reach.
    
TV vs Radio (≈ 0.05) and TV vs Newspaper (≈ 0.06)
Very weak correlations, indicating TV spending is largely independent of the other channels.
# Out:
#   Cell In[27], line 3
#     TV vs Sales (≈ 0.78)
#                  ^
# SyntaxError: invalid character '≈' (U+2248)

# %%
sns.heatmap(data.corr(),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
x=df.drop('Sales',axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 x=df.drop('Sales',axis=1)
#
# NameError: name 'df' is not defined

# %%
x = data[['TV']]
y=data.Sales

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x_train,y_train)
y_predict=LR.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.46138746336817515

# %%
print("MSE : ",mean_squared_error(y_test,y_predict))
print("MAE : ",mean_absolute_error(y_test,y_predict))
print("RMSE : ",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE :  13.06226628830567
# MAE :  2.990565035759226
# RMSE :  3.6141757412037494

# %%
x = data[['Radio']]
y=data.Sales

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x_train,y_train)
y_predict=LR.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.37864501183785726

# %%
print("MSE : ",mean_squared_error(y_test,y_predict))
print("MAE : ",mean_absolute_error(y_test,y_predict))
print("RMSE : ",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE :  15.068910882943161
# MAE :  3.268917036469783
# RMSE :  3.881869508747449

# %%
x = data[['Newspaper']]
y=data.Sales

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x_train,y_train)
y_predict=LR.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# -0.11728796161004906

# %%
print("MSE : ",mean_squared_error(y_test,y_predict))
print("MAE : ",mean_absolute_error(y_test,y_predict))
print("RMSE : ",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE :  27.096125475528662
# MAE :  3.992290912504232
# RMSE :  5.205393882841976

# %%
x = data[['TV','Radio']]
y=data.Sales

# %%
x
# Out:
#         TV  Radio
# 0    230.1   37.8
# 1     44.5   39.3
# 2     17.2   45.9
# 3    151.5   41.3
# 4    180.8   10.8
# ..     ...    ...
# 195   38.2    3.7
# 196   94.2    4.9
# 197  177.0    9.3
# 198  283.6   42.0
# 199  232.1    8.6
#
# [200 rows x 2 columns]
